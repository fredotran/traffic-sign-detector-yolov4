# %% [markdown]
# # Using YOLOv4 and OpenCV 4 to detect custom objects (Traffic Road Signs)
#
# I wanted to try to use OpenCV and YoloV4 in order to detect to detect custom objects (Traffic Road Signs), this is what this notebook will be about.
#
# *Thank you Joseph Redmon and Ali Farhadi for their incredible work on YOLO object detector* : **YOLOv3: An Incremental Improvement**, *Redmon, Joseph and Farhadi, Ali* ; arXiv, 2018.
#
# This paper was my main inspiration for this notebook.

# %%
# import useful libraries
import os
import numpy as np
import cv2
print('OpenCV version : ', cv2. __version__)
print(cv2.cuda.getCudaEnabledDeviceCount())
# Out:
# OpenCV version :  4.5.1
# 1

# %% [markdown]
# ### Load YoloV3 models with pre-trained weights

# %%
# function to load our classes names
def read_classes(file):
    """ Read the classes files and extract the classes' names in it""" 
    classNames = []    
    with open(file, 'rt') as f:
        classNames = f.read().rstrip('\n').split('\n')
   
    return classNames

# %%
# test our function read_classes
img_file = './data/obj.names'
classNames = read_classes(img_file)
print("Classes' names :\n", classNames)
# Out:
# Classes' names :
#  ['crosswalk', 'speedlimit', 'stop', 'trafficlight']

# %% [markdown]
# ### YoloV4 weights and cfg files
#
# In this part we'll upload YoloV3 Weights and cfg files in order to input them into ***cv2.dnn.readNetFromDarknet()*** and build our forward propagation with OpenCV.

# %%
# load the model config and weights
modelConfig_path = './cfg/yolov4-rds-colab.cfg'
modelWeights_path = './models/yolov4-rds-colab_best_last.weights'

# read the model cfg and weights with the cv2 DNN module
neural_net = cv2.dnn.readNetFromDarknet(modelConfig_path, modelWeights_path)
# set the preferable Backend to GPU
neural_net.setPreferableBackend(cv2.dnn.DNN_BACKEND_CUDA)
neural_net.setPreferableTarget(cv2.dnn.DNN_TARGET_CUDA)

# confidence and non-max suppression threshold for this YoloV3 version
confidenceThreshold = 0.4
nmsThreshold = 0.2

# %% [markdown]
# ## Function creation for object detection
#
# In this part, we'll define the object detection function which allows us to get **the output of the three YOLO layers (82,94,106)** and select **the best bounding box** to put on the detected object, the layers' outputs are in the format :
# - The confidence probability (if there is an object or not in the frame)
# - (x,y) coordinates of the center of the object
# - (height, width) of the frame
# - All the scores of the detected object (if there is an object detected, which one is it?)
#
# We know that the first 5 elements of the results ouputs are not the "scores", **i.e.** : *the 80 classes probabilities of what kind of object is detected*. That's why we'll start to store our outputs layers' values in different lists, the first one will stock all the **scores** from the fifth element to the last element (85th), then we'll collect the first 5 elements.
#
# For the 5th to 85th elements corresponding to *the objects scores*, we'll take the maximum value which will represent the **highest probability** about what's the object's class.
#
# #### Object detection function
#
# Based on what we've detailed above, we'll write an object detection function.

# %%
def object_detection(outputs, input_frame):
    """ This function will allow us to draw bounding boxes on detected objects in frames (images) """
    # first we'll collect the height, width and channel of the input frame (3 if the image is RGB, 1 if it's grayscale)
    height, width, channel = input_frame.shape
    
    # we'll create category lists to store the layers' output values 
    bounding_boxes = []
    class_objects = []
    confidence_probs = []
    
    # Knowing that there are 3 YOLO layers, we'll browsing them and their outputs using this :
    for result in outputs:        
        for values in result:
            
            scores = values[5:] # we know that the class probabilities are from the 5th values
            indices_object = np.argmax(scores) # get the indice of the max score
            confidence_probability = scores[indices_object] # store the maximum value of the indice found
            
            # in order to have a proper detection, we'll eliminate the weakest probability detection by imposing a threshold
            if confidence_probability > confidenceThreshold:   
                
                # get the pixel values corresponding to the scaling of the bounding box coordinates to the initial frame
                box_detected = values[0:4] * np.array([width, height, width, height])                                 
                # get the top left corner coordinates by extracting values from box_detected and perform calculations
                x, y, w, h = box_detected
                # we're converting the coordinates to int because OpenCV doesn't allow floats for bounding boxes
                x = int(x - (w/2))
                y = int(y - (h/2))
                
                # adding the good detected boxe in the bounding boxes list created
                bounding_boxes.append([x,y,w,h])                
                # adding the detected objects indices in the class objects list 
                class_objects.append(indices_object)                
                # adding the max value of the object score (confidence) in the confidences_probs list
                confidence_probs.append(float(confidence_probability))    
    
    return bounding_boxes, class_objects, confidence_probs

# %% [markdown]
# #### Non-max suppresion function
#
# When we're doing object detection with YoloV3, the algorithm outputs several bounding boxes. In order to keep the best bounding box we'll need to perform a maximizimation technique called **non-max suppression**, this method will allow us to keep the bounding box with the highest probability and eliminate the others.

# %%
def nms_bbox(bounding_boxes, confidence_probs, confidenceThreshold, nmsThreshold):
    """This function performs non-max suppression on all the bounding boxes detected and keeps the best one"""    
    #Using OpenCV DNN non-max supression to get the best bounding box of the detected object (retrieve the indices)
    indices_bbox = cv2.dnn.NMSBoxes(bounding_boxes, confidence_probs, confidenceThreshold, nmsThreshold)   
    print('Number of objects detected : ', len(indices_bbox), '\n')
    
    return indices_bbox

# %% [markdown]
# #### Drawing box function
#
# Now, we have only one bounding box left (the best one) and we'll just need to draw the corresponding box.

# %%
def box_drawing(input_frame, indices, bounding_boxes, class_objects, confidence_probs, classNames, color=(0,255,255), thickness=2):
    """ Drawing the detected objects boxes """
    # once we have the indices, we'll extract the values of x,y,w,h of the best bounding boxes and stores it.
    for i in indices:
        i = i[0]
        final_box = bounding_boxes[i]
    # we'll retrieve the bounding boxes values (coordinates) now and use them to draw our boxes.
        x, y, w, h = final_box[0], final_box[1], final_box[2], final_box[3]
        x, y, w, h = int(x), int(y), int(w), int(h)        
        print('Bounding box coordinates in the frame : ', 'x : ', x,'|| y : ',y,'|| w : ',w,'|| h :',h , '\n')
    
        cv2.rectangle(input_frame, (x,y), (x+w,y+h),  color, 2)
        cv2.putText(input_frame, f'{classNames[class_objects[i]].upper()} {int(confidence_probs[i]*100)}%',
                        (x, y-5), cv2.FONT_HERSHEY_SIMPLEX, 0.5,  color, 1)

# %% [markdown]
# ####  Blob function
#
# OpenCV uses blob techniques to extract features from an image and allows detection. In order to be able to do forward propagation on our images or videos, we'll need to convert our images to **OpenCV blob's format**.

# %%
def convert_to_blob(input_frame, network, height, width):
    """ This function allow us to convert a frame/image into blob format for OpenCV DNN"""    
    blob = cv2.dnn.blobFromImage(input_frame, 1/255, (height,width), [0,0,0], 1, crop=False)
    network.setInput(blob)
    # get the YOLO output layers numbers (names), these layers will be useful for the detection part
    # the layer's name : yolo_82, yolo_94, yolo_106
    yoloLayers = network.getLayerNames()
    outputLayers = [(yoloLayers[i[0]-1]) for i in network.getUnconnectedOutLayers()]
    # Doing forward propagation with OpenCV
    outputs = network.forward(outputLayers)
    
    return outputs

# %% [markdown]
# ### Test on video files
#
# These blocks will run object detection on videos in our **video** folder.

# %%
# method to load our video from directory
import os 

def load_video(video):    
    """ Return the video by inputing the title of the video """ 
    # get the video path and load the video
    video_path = os.path.join('videos', video)
    
    return video_path

# %%
cap_video = cv2.VideoCapture(load_video('traffic_light_test6.mp4'))

network = neural_net
# we can decrease the height and width but the minimum is 320x320.
height, width = 320,320

# save the video with object detections
frame_width = int(cap_video.get(3))
frame_height = int(cap_video.get(4))
video_frames_save = cv2.VideoWriter('./results/vids/resultvidcolab6.avi',cv2.VideoWriter_fourcc('M','J','P','G'), 25, (frame_width,frame_height))

while cap_video.isOpened():
    success, video_frames = cap_video.read()
    # if 'video_frames' is read correctly 'success' is True
    if not success:
        print("Can't receive frame (stream end?). Exiting ...")
        break
        
    # using convert_to_blob function : 
    outputs = convert_to_blob(video_frames, network, height, width)    
    # apply object detection on the video file
    bounding_boxes, class_objects, confidence_probs = object_detection(outputs, video_frames)   
    # perform non-max suppression
    indices = nms_bbox(bounding_boxes, confidence_probs, confidenceThreshold, nmsThreshold)
    # draw the boxes
    box_drawing(video_frames, indices, bounding_boxes, class_objects, confidence_probs, classNames, color=(0,255,255), thickness=2)
  
    # save the video
    video_frames_save.write(video_frames)
    
    cv2.imshow('Object Detection in videos', video_frames)         
    
    if cv2.waitKey(1) == ord('q'):
        break
        
cap_video.release()
cv2.destroyAllWindows()
# Out:
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  367 || y :  236 || w :  43 || h : 119
#
# Bounding box coordinates in the frame :  x :  238 || y :  213 || w :  70 || h : 130
#
# Bounding box coordinates in the frame :  x :  437 || y :  208 || w :  62 || h : 145
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  430 || y :  201 || w :  56 || h : 150
#
# Bounding box coordinates in the frame :  x :  344 || y :  220 || w :  45 || h : 129
#
# Bounding box coordinates in the frame :  x :  217 || y :  196 || w :  62 || h : 139
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  430 || y :  202 || w :  56 || h : 150
#
# Bounding box coordinates in the frame :  x :  344 || y :  219 || w :  45 || h : 131
#
# Bounding box coordinates in the frame :  x :  218 || y :  196 || w :  62 || h : 139
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  319 || y :  217 || w :  51 || h : 108
#
# Bounding box coordinates in the frame :  x :  204 || y :  177 || w :  52 || h : 159
#
# Bounding box coordinates in the frame :  x :  407 || y :  180 || w :  51 || h : 166
#
# Bounding box coordinates in the frame :  x :  471 || y :  201 || w :  158 || h : 153
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  315 || y :  198 || w :  46 || h : 132
#
# Bounding box coordinates in the frame :  x :  399 || y :  176 || w :  51 || h : 163
#
# Bounding box coordinates in the frame :  x :  184 || y :  172 || w :  68 || h : 141
#
# Number of objects detected :  5
#
# Bounding box coordinates in the frame :  x :  316 || y :  199 || w :  42 || h : 108
#
# Bounding box coordinates in the frame :  x :  182 || y :  176 || w :  68 || h : 121
#
# Bounding box coordinates in the frame :  x :  395 || y :  156 || w :  51 || h : 173
#
# Bounding box coordinates in the frame :  x :  440 || y :  189 || w :  169 || h : 170
#
# Bounding box coordinates in the frame :  x :  561 || y :  -3 || w :  67 || h : 140
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  310 || y :  176 || w :  43 || h : 134
#
# Bounding box coordinates in the frame :  x :  180 || y :  157 || w :  64 || h : 140
#
# Bounding box coordinates in the frame :  x :  380 || y :  152 || w :  55 || h : 153
#
# Bounding box coordinates in the frame :  x :  448 || y :  176 || w :  150 || h : 172
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  177 || y :  160 || w :  70 || h : 127
#
# Bounding box coordinates in the frame :  x :  311 || y :  172 || w :  43 || h : 130
#
# Bounding box coordinates in the frame :  x :  380 || y :  150 || w :  55 || h : 151
#
# Bounding box coordinates in the frame :  x :  450 || y :  173 || w :  143 || h : 177
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  176 || y :  160 || w :  71 || h : 127
#
# Bounding box coordinates in the frame :  x :  311 || y :  173 || w :  43 || h : 129
#
# Bounding box coordinates in the frame :  x :  380 || y :  150 || w :  55 || h : 151
#
# Bounding box coordinates in the frame :  x :  450 || y :  173 || w :  144 || h : 176
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  306 || y :  157 || w :  45 || h : 142
#
# Bounding box coordinates in the frame :  x :  380 || y :  153 || w :  56 || h : 136
#
# Bounding box coordinates in the frame :  x :  180 || y :  156 || w :  67 || h : 124
#
# Bounding box coordinates in the frame :  x :  445 || y :  167 || w :  150 || h : 186
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  174 || y :  141 || w :  66 || h : 130
#
# Bounding box coordinates in the frame :  x :  378 || y :  140 || w :  59 || h : 132
#
# Bounding box coordinates in the frame :  x :  301 || y :  159 || w :  43 || h : 121
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  379 || y :  136 || w :  54 || h : 132
#
# Bounding box coordinates in the frame :  x :  173 || y :  140 || w :  63 || h : 121
#
# Bounding box coordinates in the frame :  x :  289 || y :  151 || w :  50 || h : 122
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  289 || y :  154 || w :  48 || h : 105
#
# Bounding box coordinates in the frame :  x :  172 || y :  118 || w :  57 || h : 152
#
# Bounding box coordinates in the frame :  x :  374 || y :  127 || w :  52 || h : 147
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  288 || y :  157 || w :  48 || h : 94
#
# Bounding box coordinates in the frame :  x :  167 || y :  118 || w :  63 || h : 141
#
# Bounding box coordinates in the frame :  x :  372 || y :  114 || w :  50 || h : 157
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  288 || y :  157 || w :  48 || h : 94
#
# Bounding box coordinates in the frame :  x :  168 || y :  117 || w :  63 || h : 142
#
# Bounding box coordinates in the frame :  x :  371 || y :  115 || w :  51 || h : 157
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  289 || y :  153 || w :  47 || h : 96
#
# Bounding box coordinates in the frame :  x :  166 || y :  117 || w :  63 || h : 137
#
# Bounding box coordinates in the frame :  x :  371 || y :  112 || w :  49 || h : 154
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  284 || y :  130 || w :  48 || h : 130
#
# Bounding box coordinates in the frame :  x :  370 || y :  114 || w :  49 || h : 146
#
# Bounding box coordinates in the frame :  x :  164 || y :  118 || w :  67 || h : 128
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  284 || y :  132 || w :  48 || h : 120
#
# Bounding box coordinates in the frame :  x :  165 || y :  102 || w :  61 || h : 145
#
# Bounding box coordinates in the frame :  x :  371 || y :  111 || w :  49 || h : 147
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  281 || y :  134 || w :  48 || h : 108
#
# Bounding box coordinates in the frame :  x :  150 || y :  101 || w :  70 || h : 140
#
# Bounding box coordinates in the frame :  x :  370 || y :  95 || w :  47 || h : 156
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  279 || y :  129 || w :  45 || h : 109
#
# Bounding box coordinates in the frame :  x :  144 || y :  106 || w :  70 || h : 127
#
# Bounding box coordinates in the frame :  x :  346 || y :  95 || w :  57 || h : 147
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  279 || y :  129 || w :  45 || h : 109
#
# Bounding box coordinates in the frame :  x :  144 || y :  106 || w :  70 || h : 128
#
# Bounding box coordinates in the frame :  x :  346 || y :  95 || w :  57 || h : 147
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  141 || y :  106 || w :  71 || h : 121
#
# Bounding box coordinates in the frame :  x :  278 || y :  129 || w :  42 || h : 107
#
# Bounding box coordinates in the frame :  x :  346 || y :  101 || w :  56 || h : 133
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  344 || y :  100 || w :  57 || h : 130
#
# Bounding box coordinates in the frame :  x :  139 || y :  103 || w :  63 || h : 124
#
# Bounding box coordinates in the frame :  x :  270 || y :  125 || w :  43 || h : 112
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  339 || y :  98 || w :  55 || h : 138
#
# Bounding box coordinates in the frame :  x :  136 || y :  101 || w :  61 || h : 129
#
# Bounding box coordinates in the frame :  x :  257 || y :  117 || w :  46 || h : 119
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  256 || y :  135 || w :  48 || h : 94
#
# Bounding box coordinates in the frame :  x :  132 || y :  99 || w :  67 || h : 134
#
# Bounding box coordinates in the frame :  x :  338 || y :  96 || w :  53 || h : 144
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  252 || y :  135 || w :  49 || h : 94
#
# Bounding box coordinates in the frame :  x :  129 || y :  99 || w :  67 || h : 138
#
# Bounding box coordinates in the frame :  x :  337 || y :  95 || w :  51 || h : 149
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  252 || y :  135 || w :  49 || h : 95
#
# Bounding box coordinates in the frame :  x :  129 || y :  99 || w :  67 || h : 138
#
# Bounding box coordinates in the frame :  x :  337 || y :  95 || w :  51 || h : 149
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  252 || y :  135 || w :  48 || h : 98
#
# Bounding box coordinates in the frame :  x :  336 || y :  94 || w :  50 || h : 153
#
# Bounding box coordinates in the frame :  x :  116 || y :  108 || w :  78 || h : 121
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  252 || y :  136 || w :  48 || h : 100
#
# Bounding box coordinates in the frame :  x :  117 || y :  107 || w :  74 || h : 126
#
# Bounding box coordinates in the frame :  x :  337 || y :  92 || w :  48 || h : 162
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  250 || y :  133 || w :  49 || h : 111
#
# Bounding box coordinates in the frame :  x :  114 || y :  107 || w :  76 || h : 130
#
# Bounding box coordinates in the frame :  x :  336 || y :  108 || w :  48 || h : 148
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  252 || y :  135 || w :  47 || h : 110
#
# Bounding box coordinates in the frame :  x :  116 || y :  107 || w :  76 || h : 131
#
# Bounding box coordinates in the frame :  x :  336 || y :  109 || w :  51 || h : 148
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  252 || y :  137 || w :  48 || h : 107
#
# Bounding box coordinates in the frame :  x :  116 || y :  105 || w :  77 || h : 134
#
# Bounding box coordinates in the frame :  x :  337 || y :  109 || w :  50 || h : 148
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  252 || y :  137 || w :  48 || h : 107
#
# Bounding box coordinates in the frame :  x :  116 || y :  105 || w :  77 || h : 134
#
# Bounding box coordinates in the frame :  x :  337 || y :  109 || w :  51 || h : 147
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  253 || y :  132 || w :  45 || h : 121
#
# Bounding box coordinates in the frame :  x :  336 || y :  111 || w :  50 || h : 150
#
# Bounding box coordinates in the frame :  x :  117 || y :  107 || w :  74 || h : 134
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  337 || y :  112 || w :  49 || h : 147
#
# Bounding box coordinates in the frame :  x :  254 || y :  132 || w :  44 || h : 123
#
# Bounding box coordinates in the frame :  x :  120 || y :  109 || w :  68 || h : 136
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  337 || y :  111 || w :  49 || h : 147
#
# Bounding box coordinates in the frame :  x :  254 || y :  142 || w :  49 || h : 105
#
# Bounding box coordinates in the frame :  x :  120 || y :  109 || w :  68 || h : 133
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  252 || y :  131 || w :  45 || h : 124
#
# Bounding box coordinates in the frame :  x :  337 || y :  108 || w :  48 || h : 153
#
# Bounding box coordinates in the frame :  x :  118 || y :  108 || w :  71 || h : 132
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  253 || y :  140 || w :  49 || h : 107
#
# Bounding box coordinates in the frame :  x :  117 || y :  107 || w :  73 || h : 135
#
# Bounding box coordinates in the frame :  x :  337 || y :  109 || w :  50 || h : 149
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  253 || y :  140 || w :  49 || h : 107
#
# Bounding box coordinates in the frame :  x :  117 || y :  107 || w :  73 || h : 135
#
# Bounding box coordinates in the frame :  x :  337 || y :  109 || w :  50 || h : 148
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  249 || y :  135 || w :  52 || h : 110
#
# Bounding box coordinates in the frame :  x :  130 || y :  102 || w :  67 || h : 143
#
# Bounding box coordinates in the frame :  x :  340 || y :  92 || w :  47 || h : 164
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  249 || y :  137 || w :  52 || h : 100
#
# Bounding box coordinates in the frame :  x :  340 || y :  95 || w :  48 || h : 153
#
# Bounding box coordinates in the frame :  x :  130 || y :  101 || w :  66 || h : 142
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  339 || y :  97 || w :  50 || h : 143
#
# Bounding box coordinates in the frame :  x :  129 || y :  99 || w :  69 || h : 136
#
# Bounding box coordinates in the frame :  x :  248 || y :  138 || w :  53 || h : 95
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  339 || y :  96 || w :  52 || h : 141
#
# Bounding box coordinates in the frame :  x :  128 || y :  101 || w :  70 || h : 128
#
# Bounding box coordinates in the frame :  x :  255 || y :  137 || w :  49 || h : 89
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  339 || y :  92 || w :  50 || h : 148
#
# Bounding box coordinates in the frame :  x :  252 || y :  125 || w :  52 || h : 102
#
# Bounding box coordinates in the frame :  x :  128 || y :  100 || w :  70 || h : 126
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  339 || y :  92 || w :  50 || h : 148
#
# Bounding box coordinates in the frame :  x :  252 || y :  125 || w :  52 || h : 102
#
# Bounding box coordinates in the frame :  x :  128 || y :  100 || w :  70 || h : 126
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  253 || y :  125 || w :  50 || h : 102
#
# Bounding box coordinates in the frame :  x :  340 || y :  92 || w :  49 || h : 144
#
# Bounding box coordinates in the frame :  x :  118 || y :  91 || w :  72 || h : 132
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  253 || y :  125 || w :  50 || h : 101
#
# Bounding box coordinates in the frame :  x :  130 || y :  85 || w :  65 || h : 145
#
# Bounding box coordinates in the frame :  x :  341 || y :  91 || w :  47 || h : 145
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  248 || y :  114 || w :  52 || h : 115
#
# Bounding box coordinates in the frame :  x :  115 || y :  88 || w :  74 || h : 133
#
# Bounding box coordinates in the frame :  x :  341 || y :  79 || w :  46 || h : 154
#
# Bounding box coordinates in the frame :  x :  396 || y :  106 || w :  125 || h : 241
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  115 || y :  88 || w :  75 || h : 122
#
# Bounding box coordinates in the frame :  x :  247 || y :  115 || w :  53 || h : 100
#
# Bounding box coordinates in the frame :  x :  340 || y :  77 || w :  47 || h : 148
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  250 || y :  87 || w :  47 || h : 140
#
# Bounding box coordinates in the frame :  x :  337 || y :  72 || w :  48 || h : 154
#
# Bounding box coordinates in the frame :  x :  111 || y :  73 || w :  71 || h : 135
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  250 || y :  88 || w :  47 || h : 139
#
# Bounding box coordinates in the frame :  x :  337 || y :  72 || w :  48 || h : 154
#
# Bounding box coordinates in the frame :  x :  111 || y :  73 || w :  71 || h : 135
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  111 || y :  70 || w :  72 || h : 137
#
# Bounding box coordinates in the frame :  x :  249 || y :  91 || w :  49 || h : 127
#
# Bounding box coordinates in the frame :  x :  334 || y :  67 || w :  50 || h : 158
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  110 || y :  67 || w :  71 || h : 140
#
# Bounding box coordinates in the frame :  x :  248 || y :  93 || w :  50 || h : 118
#
# Bounding box coordinates in the frame :  x :  335 || y :  55 || w :  50 || h : 164
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  247 || y :  92 || w :  51 || h : 115
#
# Bounding box coordinates in the frame :  x :  108 || y :  66 || w :  71 || h : 136
#
# Bounding box coordinates in the frame :  x :  333 || y :  55 || w :  51 || h : 157
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  107 || y :  65 || w :  70 || h : 136
#
# Bounding box coordinates in the frame :  x :  246 || y :  91 || w :  50 || h : 116
#
# Bounding box coordinates in the frame :  x :  332 || y :  54 || w :  54 || h : 158
