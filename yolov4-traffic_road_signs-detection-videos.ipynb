# %% [markdown]
# # Using YOLOv4 and OpenCV 4 to detect custom objects (Traffic Road Signs)
#
# I wanted to try to use OpenCV and YoloV4 in order to detect to detect custom objects (Traffic Road Signs), this is what this notebook will be about.
#
# *Thank you Joseph Redmon and Ali Farhadi for their incredible work on **YOLO object detector** : **[YOLOv3: An Incremental Improvement](https://arxiv.org/abs/1804.02767)**, *Redmon, Joseph and Farhadi, Ali* ; arXiv, 2018.
#
# *Thank you AlexeyAB for your* **[YOLOv4 : Algorithm](https://github.com/AlexeyAB/darknet)**.

# %%
# import useful libraries
import os
import numpy as np
import cv2
from yolo_utils import *

print('OpenCV version : ', cv2. __version__)
print(cv2.cuda.getCudaEnabledDeviceCount())
# Out:
# OpenCV version :  4.5.1
# 1

# %% [markdown]
# ### Load YoloV4 labels

# %%
# load the obj/classes names
obj_file = './data/obj.names'
classNames = read_classes(obj_file)
print("Classes' names :\n", classNames)
# Out:
# Classes' names :
#  ['crosswalk', 'speedlimit', 'stop', 'trafficlight']

# %% [markdown]
# ### YoloV4 weights and cfg files
#
# In this part we'll upload YoloV3 Weights and cfg files in order to input them into ***cv2.dnn.readNetFromDarknet()*** and build our forward propagation with OpenCV.

# %%
# load the model config and weights
modelConfig_path = './cfg/yolov4-rds.cfg'
modelWeights_path = './weights/yolov4-rds_last.weights'

# read the model cfg and weights with the cv2 DNN module
neural_net = cv2.dnn.readNetFromDarknet(modelConfig_path, modelWeights_path)
# set the preferable Backend to GPU for performing faster
neural_net.setPreferableBackend(cv2.dnn.DNN_BACKEND_CUDA)
neural_net.setPreferableTarget(cv2.dnn.DNN_TARGET_CUDA)

# %% [markdown]
# ### Test on video files
#
# These blocks will run object detection on videos in our **'/inputs/video/[ClassesNames]/'**  folder.

# %%
# confidence and non-max suppression threshold for this YoloV3 version
confidenceThreshold = 0.5
nmsThreshold = 0.1

# defining the input frame resolution for the neural network to process
# we can decrease the height and width but the minimum is 320x320.
network = neural_net
height, width = 320,320

# load the video
cap_video = load_video('/traffic-lights/traffic_light_test6.mp4')

# save the video with object detections
frame_width = int(cap_video.get(3))
frame_height = int(cap_video.get(4))
video_frames_save = cv2.VideoWriter('./results/videos/resultvidcolab6.avi',cv2.VideoWriter_fourcc('M','J','P','G'), 25, (frame_width,frame_height))

while cap_video.isOpened():
    success, video_frames = cap_video.read()
    # if 'video_frames' is read correctly 'success' is True
    if not success:
        print("Can't receive frame (stream end?). Exiting ...")
        break
        
    # using convert_to_blob function : 
    outputs = convert_to_blob(video_frames, network, height, width)    
    # apply object detection on the video file
    bounding_boxes, class_objects, confidence_probs = object_detection(outputs, video_frames, confidenceThreshold)   
    # perform non-max suppression
    indices = nms_bbox(bounding_boxes, confidence_probs, confidenceThreshold, nmsThreshold)
    # draw the boxes
    box_drawing(video_frames, indices, bounding_boxes, class_objects, confidence_probs, classNames, color=(0,255,255), thickness=2)
  
    # save the video
    video_frames_save.write(video_frames)
    
    cv2.imshow('Object Detection in videos', video_frames)         
    
    if cv2.waitKey(1) == ord('q'):
        break
        
cap_video.release()
cv2.destroyAllWindows()
# Out:
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  364 || y :  243 || w :  54 || h : 103
#
# Bounding box coordinates in the frame :  x :  440 || y :  211 || w :  69 || h : 141
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  343 || y :  232 || w :  53 || h : 103
#
# Bounding box coordinates in the frame :  x :  423 || y :  194 || w :  77 || h : 164
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  344 || y :  232 || w :  53 || h : 103
#
# Bounding box coordinates in the frame :  x :  423 || y :  194 || w :  77 || h : 164
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  317 || y :  218 || w :  59 || h : 97
#
# Bounding box coordinates in the frame :  x :  403 || y :  172 || w :  66 || h : 181
#
# Bounding box coordinates in the frame :  x :  207 || y :  175 || w :  54 || h : 160
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  315 || y :  208 || w :  53 || h : 112
#
# Bounding box coordinates in the frame :  x :  392 || y :  171 || w :  73 || h : 170
#
# Bounding box coordinates in the frame :  x :  203 || y :  160 || w :  55 || h : 171
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  308 || y :  195 || w :  57 || h : 106
#
# Bounding box coordinates in the frame :  x :  387 || y :  147 || w :  72 || h : 190
#
# Bounding box coordinates in the frame :  x :  467 || y :  162 || w :  142 || h : 203
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  307 || y :  194 || w :  53 || h : 101
#
# Bounding box coordinates in the frame :  x :  467 || y :  151 || w :  131 || h : 222
#
# Bounding box coordinates in the frame :  x :  187 || y :  149 || w :  59 || h : 150
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  305 || y :  185 || w :  55 || h : 107
#
# Bounding box coordinates in the frame :  x :  182 || y :  146 || w :  66 || h : 150
#
# Bounding box coordinates in the frame :  x :  465 || y :  140 || w :  131 || h : 243
#
# Bounding box coordinates in the frame :  x :  394 || y :  154 || w :  59 || h : 149
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  305 || y :  184 || w :  56 || h : 108
#
# Bounding box coordinates in the frame :  x :  182 || y :  146 || w :  66 || h : 151
#
# Bounding box coordinates in the frame :  x :  465 || y :  139 || w :  130 || h : 245
#
# Bounding box coordinates in the frame :  x :  394 || y :  154 || w :  59 || h : 150
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  300 || y :  174 || w :  56 || h : 109
#
# Bounding box coordinates in the frame :  x :  184 || y :  139 || w :  66 || h : 147
#
# Bounding box coordinates in the frame :  x :  463 || y :  130 || w :  128 || h : 262
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  297 || y :  167 || w :  54 || h : 108
#
# Bounding box coordinates in the frame :  x :  178 || y :  122 || w :  69 || h : 164
#
# Bounding box coordinates in the frame :  x :  381 || y :  137 || w :  63 || h : 141
#
# Bounding box coordinates in the frame :  x :  453 || y :  161 || w :  152 || h : 163
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  301 || y :  169 || w :  49 || h : 89
#
# Bounding box coordinates in the frame :  x :  375 || y :  123 || w :  72 || h : 156
#
# Bounding box coordinates in the frame :  x :  451 || y :  151 || w :  153 || h : 181
#
# Bounding box coordinates in the frame :  x :  178 || y :  116 || w :  59 || h : 156
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  373 || y :  117 || w :  67 || h : 152
#
# Bounding box coordinates in the frame :  x :  292 || y :  154 || w :  49 || h : 105
#
# Bounding box coordinates in the frame :  x :  174 || y :  118 || w :  62 || h : 148
#
# Bounding box coordinates in the frame :  x :  460 || y :  149 || w :  143 || h : 182
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  291 || y :  151 || w :  49 || h : 104
#
# Bounding box coordinates in the frame :  x :  370 || y :  111 || w :  63 || h : 161
#
# Bounding box coordinates in the frame :  x :  170 || y :  107 || w :  67 || h : 161
#
# Bounding box coordinates in the frame :  x :  450 || y :  139 || w :  155 || h : 197
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  291 || y :  151 || w :  49 || h : 105
#
# Bounding box coordinates in the frame :  x :  370 || y :  111 || w :  63 || h : 161
#
# Bounding box coordinates in the frame :  x :  170 || y :  107 || w :  67 || h : 160
#
# Bounding box coordinates in the frame :  x :  451 || y :  138 || w :  153 || h : 198
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  290 || y :  158 || w :  51 || h : 87
#
# Bounding box coordinates in the frame :  x :  369 || y :  107 || w :  65 || h : 162
#
# Bounding box coordinates in the frame :  x :  167 || y :  106 || w :  67 || h : 155
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  285 || y :  151 || w :  56 || h : 87
#
# Bounding box coordinates in the frame :  x :  362 || y :  109 || w :  73 || h : 152
#
# Bounding box coordinates in the frame :  x :  168 || y :  107 || w :  64 || h : 150
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  283 || y :  142 || w :  55 || h : 100
#
# Bounding box coordinates in the frame :  x :  367 || y :  97 || w :  64 || h : 157
#
# Bounding box coordinates in the frame :  x :  164 || y :  88 || w :  68 || h : 171
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  281 || y :  137 || w :  52 || h : 100
#
# Bounding box coordinates in the frame :  x :  364 || y :  90 || w :  61 || h : 165
#
# Bounding box coordinates in the frame :  x :  151 || y :  93 || w :  68 || h : 151
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  272 || y :  129 || w :  58 || h : 107
#
# Bounding box coordinates in the frame :  x :  146 || y :  92 || w :  74 || h : 150
#
# Bounding box coordinates in the frame :  x :  356 || y :  91 || w :  67 || h : 156
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  272 || y :  130 || w :  58 || h : 106
#
# Bounding box coordinates in the frame :  x :  146 || y :  92 || w :  74 || h : 150
#
# Bounding box coordinates in the frame :  x :  356 || y :  91 || w :  66 || h : 157
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  272 || y :  132 || w :  55 || h : 101
#
# Bounding box coordinates in the frame :  x :  148 || y :  89 || w :  65 || h : 153
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  266 || y :  134 || w :  54 || h : 88
#
# Bounding box coordinates in the frame :  x :  338 || y :  96 || w :  75 || h : 137
#
# Bounding box coordinates in the frame :  x :  143 || y :  87 || w :  63 || h : 154
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  331 || y :  93 || w :  79 || h : 146
#
# Bounding box coordinates in the frame :  x :  263 || y :  133 || w :  55 || h : 88
#
# Bounding box coordinates in the frame :  x :  142 || y :  82 || w :  60 || h : 154
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  335 || y :  88 || w :  67 || h : 158
#
# Bounding box coordinates in the frame :  x :  257 || y :  142 || w :  52 || h : 81
#
# Bounding box coordinates in the frame :  x :  135 || y :  85 || w :  68 || h : 162
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  254 || y :  139 || w :  54 || h : 87
#
# Bounding box coordinates in the frame :  x :  336 || y :  83 || w :  60 || h : 171
#
# Bounding box coordinates in the frame :  x :  131 || y :  86 || w :  71 || h : 162
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  254 || y :  139 || w :  54 || h : 87
#
# Bounding box coordinates in the frame :  x :  336 || y :  83 || w :  60 || h : 171
#
# Bounding box coordinates in the frame :  x :  131 || y :  86 || w :  71 || h : 162
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  254 || y :  134 || w :  50 || h : 97
#
# Bounding box coordinates in the frame :  x :  332 || y :  85 || w :  64 || h : 168
#
# Bounding box coordinates in the frame :  x :  130 || y :  82 || w :  70 || h : 169
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  254 || y :  138 || w :  49 || h : 93
#
# Bounding box coordinates in the frame :  x :  333 || y :  89 || w :  66 || h : 166
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  252 || y :  144 || w :  51 || h : 88
#
# Bounding box coordinates in the frame :  x :  330 || y :  92 || w :  66 || h : 164
#
# Bounding box coordinates in the frame :  x :  118 || y :  101 || w :  72 || h : 141
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  253 || y :  146 || w :  52 || h : 87
#
# Bounding box coordinates in the frame :  x :  331 || y :  94 || w :  68 || h : 163
#
# Bounding box coordinates in the frame :  x :  131 || y :  87 || w :  68 || h : 174
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  252 || y :  146 || w :  54 || h : 87
#
# Bounding box coordinates in the frame :  x :  333 || y :  93 || w :  65 || h : 162
#
# Bounding box coordinates in the frame :  x :  130 || y :  87 || w :  71 || h : 173
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  253 || y :  146 || w :  54 || h : 87
#
# Bounding box coordinates in the frame :  x :  333 || y :  93 || w :  65 || h : 162
#
# Bounding box coordinates in the frame :  x :  130 || y :  87 || w :  70 || h : 173
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  252 || y :  145 || w :  52 || h : 94
#
# Bounding box coordinates in the frame :  x :  326 || y :  108 || w :  75 || h : 150
#
# Bounding box coordinates in the frame :  x :  124 || y :  96 || w :  79 || h : 152
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  254 || y :  154 || w :  52 || h : 80
#
# Bounding box coordinates in the frame :  x :  327 || y :  108 || w :  74 || h : 150
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  254 || y :  153 || w :  53 || h : 82
#
# Bounding box coordinates in the frame :  x :  328 || y :  111 || w :  73 || h : 144
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  254 || y :  152 || w :  52 || h : 81
#
# Bounding box coordinates in the frame :  x :  332 || y :  98 || w :  66 || h : 156
#
# Bounding box coordinates in the frame :  x :  123 || y :  101 || w :  78 || h : 140
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  254 || y :  152 || w :  53 || h : 82
#
# Bounding box coordinates in the frame :  x :  336 || y :  95 || w :  60 || h : 159
#
# Bounding box coordinates in the frame :  x :  125 || y :  96 || w :  77 || h : 147
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  254 || y :  152 || w :  53 || h : 82
#
# Bounding box coordinates in the frame :  x :  336 || y :  95 || w :  60 || h : 160
#
# Bounding box coordinates in the frame :  x :  125 || y :  98 || w :  77 || h : 144
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  250 || y :  144 || w :  57 || h : 90
#
# Bounding box coordinates in the frame :  x :  340 || y :  91 || w :  54 || h : 165
#
# Bounding box coordinates in the frame :  x :  126 || y :  99 || w :  73 || h : 137
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  252 || y :  141 || w :  52 || h : 89
#
# Bounding box coordinates in the frame :  x :  338 || y :  90 || w :  58 || h : 162
#
# Bounding box coordinates in the frame :  x :  130 || y :  87 || w :  72 || h : 166
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  254 || y :  139 || w :  50 || h : 88
#
# Bounding box coordinates in the frame :  x :  335 || y :  89 || w :  61 || h : 156
#
# Bounding box coordinates in the frame :  x :  130 || y :  86 || w :  73 || h : 161
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  252 || y :  129 || w :  52 || h : 96
#
# Bounding box coordinates in the frame :  x :  334 || y :  90 || w :  67 || h : 150
#
# Bounding box coordinates in the frame :  x :  131 || y :  90 || w :  72 || h : 150
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  251 || y :  127 || w :  53 || h : 97
#
# Bounding box coordinates in the frame :  x :  332 || y :  88 || w :  69 || h : 154
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  251 || y :  127 || w :  53 || h : 97
#
# Bounding box coordinates in the frame :  x :  332 || y :  88 || w :  69 || h : 154
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  250 || y :  127 || w :  56 || h : 96
#
# Bounding box coordinates in the frame :  x :  336 || y :  81 || w :  65 || h : 154
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  250 || y :  126 || w :  55 || h : 94
#
# Bounding box coordinates in the frame :  x :  335 || y :  84 || w :  65 || h : 146
#
# Bounding box coordinates in the frame :  x :  123 || y :  83 || w :  82 || h : 145
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  249 || y :  123 || w :  52 || h : 94
#
# Bounding box coordinates in the frame :  x :  335 || y :  77 || w :  63 || h : 156
#
# Bounding box coordinates in the frame :  x :  117 || y :  84 || w :  72 || h : 139
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  248 || y :  111 || w :  53 || h : 107
#
# Bounding box coordinates in the frame :  x :  335 || y :  69 || w :  60 || h : 161
#
# Bounding box coordinates in the frame :  x :  120 || y :  78 || w :  65 || h : 144
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  248 || y :  103 || w :  54 || h : 109
#
# Bounding box coordinates in the frame :  x :  114 || y :  70 || w :  75 || h : 137
#
# Bounding box coordinates in the frame :  x :  334 || y :  65 || w :  58 || h : 164
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  248 || y :  103 || w :  54 || h : 109
#
# Bounding box coordinates in the frame :  x :  114 || y :  70 || w :  74 || h : 138
#
# Bounding box coordinates in the frame :  x :  334 || y :  64 || w :  58 || h : 164
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  248 || y :  100 || w :  52 || h : 106
#
# Bounding box coordinates in the frame :  x :  113 || y :  62 || w :  73 || h : 148
#
# Bounding box coordinates in the frame :  x :  329 || y :  51 || w :  64 || h : 175
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  113 || y :  59 || w :  71 || h : 151
#
# Bounding box coordinates in the frame :  x :  247 || y :  98 || w :  52 || h : 104
#
# Bounding box coordinates in the frame :  x :  328 || y :  48 || w :  65 || h : 176
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  247 || y :  96 || w :  51 || h : 106
#
# Bounding box coordinates in the frame :  x :  327 || y :  43 || w :  64 || h : 178
#
# Bounding box coordinates in the frame :  x :  115 || y :  50 || w :  64 || h : 166
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  246 || y :  95 || w :  50 || h : 105
#
# Bounding box coordinates in the frame :  x :  114 || y :  49 || w :  64 || h : 164
#
# Bounding box coordinates in the frame :  x :  328 || y :  41 || w :  63 || h : 181
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  112 || y :  50 || w :  66 || h : 164
#
# Bounding box coordinates in the frame :  x :  246 || y :  90 || w :  50 || h : 115
#
# Bounding box coordinates in the frame :  x :  325 || y :  62 || w :  84 || h : 136
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  245 || y :  89 || w :  50 || h : 116
#
# Bounding box coordinates in the frame :  x :  112 || y :  50 || w :  66 || h : 164
#
# Bounding box coordinates in the frame :  x :  324 || y :  62 || w :  84 || h : 136
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  108 || y :  50 || w :  72 || h : 164
#
# Bounding box coordinates in the frame :  x :  323 || y :  65 || w :  87 || h : 133
#
# Bounding box coordinates in the frame :  x :  238 || y :  103 || w :  56 || h : 89
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  108 || y :  55 || w :  69 || h : 160
#
# Bounding box coordinates in the frame :  x :  243 || y :  94 || w :  52 || h : 110
#
# Bounding box coordinates in the frame :  x :  327 || y :  65 || w :  82 || h : 137
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  240 || y :  96 || w :  57 || h : 115
#
# Bounding box coordinates in the frame :  x :  106 || y :  54 || w :  68 || h : 165
#
# Bounding box coordinates in the frame :  x :  323 || y :  66 || w :  87 || h : 141
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  236 || y :  115 || w :  60 || h : 89
#
# Bounding box coordinates in the frame :  x :  105 || y :  55 || w :  68 || h : 169
#
# Bounding box coordinates in the frame :  x :  327 || y :  64 || w :  65 || h : 164
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  237 || y :  119 || w :  56 || h : 90
#
# Bounding box coordinates in the frame :  x :  325 || y :  83 || w :  82 || h : 135
# Bounding box coordinates in the frame :  x :  105 || y :  55 || w :  68 || h : 171
#
# Bounding box coordinates in the frame :  x :  404 || y :  100 || w :  127 || h : 248
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  237 || y :  119 || w :  56 || h : 90
#
# Bounding box coordinates in the frame :  x :  325 || y :  83 || w :  82 || h : 135
#
# Bounding box coordinates in the frame :  x :  105 || y :  55 || w :  68 || h : 171
#
# Bounding box coordinates in the frame :  x :  404 || y :  99 || w :  127 || h : 249
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  242 || y :  108 || w :  56 || h : 116
#
# Bounding box coordinates in the frame :  x :  106 || y :  62 || w :  68 || h : 171
#
# Bounding box coordinates in the frame :  x :  323 || y :  84 || w :  87 || h : 136
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  106 || y :  65 || w :  67 || h : 172
#
# Bounding box coordinates in the frame :  x :  243 || y :  107 || w :  55 || h : 120
#
# Bounding box coordinates in the frame :  x :  333 || y :  57 || w :  61 || h : 190
#
# Bounding box coordinates in the frame :  x :  406 || y :  103 || w :  128 || h : 246
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  105 || y :  68 || w :  72 || h : 170
#
# Bounding box coordinates in the frame :  x :  243 || y :  107 || w :  56 || h : 121
#
# Bounding box coordinates in the frame :  x :  334 || y :  56 || w :  61 || h : 192
#
# Bounding box coordinates in the frame :  x :  410 || y :  106 || w :  124 || h : 243
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  105 || y :  68 || w :  71 || h : 172
#
# Bounding box coordinates in the frame :  x :  243 || y :  108 || w :  57 || h : 122
#
# Bounding box coordinates in the frame :  x :  332 || y :  57 || w :  65 || h : 192
#
# Bounding box coordinates in the frame :  x :  412 || y :  117 || w :  147 || h : 222
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  107 || y :  66 || w :  73 || h : 175
#
# Bounding box coordinates in the frame :  x :  248 || y :  111 || w :  54 || h : 117
#
# Bounding box coordinates in the frame :  x :  334 || y :  61 || w :  68 || h : 185
#
# Bounding box coordinates in the frame :  x :  420 || y :  117 || w :  132 || h : 221
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  107 || y :  66 || w :  73 || h : 175
#
# Bounding box coordinates in the frame :  x :  248 || y :  111 || w :  54 || h : 117
#
# Bounding box coordinates in the frame :  x :  334 || y :  61 || w :  68 || h : 185
#
# Bounding box coordinates in the frame :  x :  420 || y :  117 || w :  133 || h : 221
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  247 || y :  110 || w :  55 || h : 121
#
# Bounding box coordinates in the frame :  x :  336 || y :  60 || w :  69 || h : 188
#
# Bounding box coordinates in the frame :  x :  108 || y :  63 || w :  71 || h : 182
#
# Bounding box coordinates in the frame :  x :  425 || y :  108 || w :  126 || h : 240
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  248 || y :  110 || w :  55 || h : 121
#
# Bounding box coordinates in the frame :  x :  108 || y :  62 || w :  69 || h : 183
#
# Bounding box coordinates in the frame :  x :  337 || y :  57 || w :  72 || h : 194
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  248 || y :  111 || w :  56 || h : 122
#
# Bounding box coordinates in the frame :  x :  339 || y :  58 || w :  71 || h : 192
#
# Bounding box coordinates in the frame :  x :  109 || y :  62 || w :  68 || h : 183
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  249 || y :  111 || w :  60 || h : 123
#
# Bounding box coordinates in the frame :  x :  110 || y :  62 || w :  68 || h : 184
#
# Bounding box coordinates in the frame :  x :  343 || y :  55 || w :  66 || h : 201
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  247 || y :  131 || w :  65 || h : 92
#
# Bounding box coordinates in the frame :  x :  343 || y :  50 || w :  70 || h : 216
#
# Bounding box coordinates in the frame :  x :  110 || y :  60 || w :  65 || h : 190
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  247 || y :  131 || w :  65 || h : 92
#
# Bounding box coordinates in the frame :  x :  110 || y :  60 || w :  66 || h : 189
#
# Bounding box coordinates in the frame :  x :  343 || y :  50 || w :  70 || h : 216
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  249 || y :  135 || w :  65 || h : 94
#
# Bounding box coordinates in the frame :  x :  121 || y :  78 || w :  64 || h : 160
#
# Bounding box coordinates in the frame :  x :  345 || y :  65 || w :  69 || h : 188
#
# Bounding box coordinates in the frame :  x :  438 || y :  97 || w :  128 || h : 261
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  118 || y :  81 || w :  67 || h : 159
#
# Bounding box coordinates in the frame :  x :  248 || y :  137 || w :  67 || h : 93
#
# Bounding box coordinates in the frame :  x :  352 || y :  65 || w :  70 || h : 201
#
# Bounding box coordinates in the frame :  x :  438 || y :  89 || w :  127 || h : 275
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  111 || y :  75 || w :  69 || h : 188
#
# Bounding box coordinates in the frame :  x :  352 || y :  64 || w :  72 || h : 209
#
# Bounding box coordinates in the frame :  x :  252 || y :  138 || w :  62 || h : 96
#
# Bounding box coordinates in the frame :  x :  434 || y :  102 || w :  141 || h : 249
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  112 || y :  73 || w :  68 || h : 191
#
# Bounding box coordinates in the frame :  x :  353 || y :  62 || w :  73 || h : 215
#
# Bounding box coordinates in the frame :  x :  256 || y :  125 || w :  56 || h : 124
#
# Bounding box coordinates in the frame :  x :  433 || y :  103 || w :  143 || h : 250
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  112 || y :  72 || w :  67 || h : 194
#
# Bounding box coordinates in the frame :  x :  358 || y :  82 || w :  83 || h : 167
#
# Bounding box coordinates in the frame :  x :  262 || y :  125 || w :  58 || h : 129
#
# Bounding box coordinates in the frame :  x :  434 || y :  102 || w :  143 || h : 250
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  358 || y :  83 || w :  84 || h : 166
#
# Bounding box coordinates in the frame :  x :  112 || y :  71 || w :  66 || h : 195
#
# Bounding box coordinates in the frame :  x :  262 || y :  125 || w :  58 || h : 129
#
# Bounding box coordinates in the frame :  x :  434 || y :  102 || w :  143 || h : 250
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  362 || y :  79 || w :  78 || h : 170
#
# Bounding box coordinates in the frame :  x :  113 || y :  69 || w :  68 || h : 198
#
# Bounding box coordinates in the frame :  x :  264 || y :  126 || w :  59 || h : 126
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  363 || y :  83 || w :  81 || h : 166
#
# Bounding box coordinates in the frame :  x :  112 || y :  67 || w :  68 || h : 203
#
# Bounding box coordinates in the frame :  x :  261 || y :  140 || w :  64 || h : 105
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  363 || y :  80 || w :  89 || h : 172
#
# Bounding box coordinates in the frame :  x :  261 || y :  142 || w :  67 || h : 101
#
# Bounding box coordinates in the frame :  x :  112 || y :  66 || w :  70 || h : 203
#
# Bounding box coordinates in the frame :  x :  430 || y :  87 || w :  195 || h : 281
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  364 || y :  83 || w :  91 || h : 170
#
# Bounding box coordinates in the frame :  x :  261 || y :  141 || w :  67 || h : 104
#
# Bounding box coordinates in the frame :  x :  112 || y :  65 || w :  69 || h : 206
#
# Bounding box coordinates in the frame :  x :  455 || y :  80 || w :  140 || h : 292
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  365 || y :  86 || w :  95 || h : 166
#
# Bounding box coordinates in the frame :  x :  261 || y :  141 || w :  67 || h : 105
#
# Bounding box coordinates in the frame :  x :  111 || y :  64 || w :  70 || h : 208
#
# Bounding box coordinates in the frame :  x :  454 || y :  85 || w :  144 || h : 282
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  364 || y :  86 || w :  95 || h : 166
#
# Bounding box coordinates in the frame :  x :  261 || y :  141 || w :  67 || h : 105
#
# Bounding box coordinates in the frame :  x :  111 || y :  64 || w :  70 || h : 208
#
# Bounding box coordinates in the frame :  x :  454 || y :  85 || w :  144 || h : 282
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  367 || y :  79 || w :  95 || h : 174
#
# Bounding box coordinates in the frame :  x :  262 || y :  139 || w :  67 || h : 107
#
# Bounding box coordinates in the frame :  x :  110 || y :  64 || w :  72 || h : 208
#
# Bounding box coordinates in the frame :  x :  456 || y :  95 || w :  143 || h : 261
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  365 || y :  78 || w :  97 || h : 174
#
# Bounding box coordinates in the frame :  x :  262 || y :  140 || w :  66 || h : 105
#
# Bounding box coordinates in the frame :  x :  108 || y :  64 || w :  72 || h : 211
#
# Bounding box coordinates in the frame :  x :  454 || y :  96 || w :  146 || h : 259
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  104 || y :  65 || w :  79 || h : 210
#
# Bounding box coordinates in the frame :  x :  363 || y :  80 || w :  98 || h : 171
#
# Bounding box coordinates in the frame :  x :  260 || y :  140 || w :  67 || h : 104
#
# Bounding box coordinates in the frame :  x :  455 || y :  96 || w :  144 || h : 258
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  112 || y :  81 || w :  74 || h : 169
#
# Bounding box coordinates in the frame :  x :  363 || y :  78 || w :  98 || h : 174
#
# Bounding box coordinates in the frame :  x :  262 || y :  120 || w :  64 || h : 137
#
# Bounding box coordinates in the frame :  x :  456 || y :  94 || w :  141 || h : 260
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  110 || y :  82 || w :  74 || h : 165
#
# Bounding box coordinates in the frame :  x :  365 || y :  73 || w :  92 || h : 179
#
# Bounding box coordinates in the frame :  x :  457 || y :  91 || w :  138 || h : 266
#
# Bounding box coordinates in the frame :  x :  259 || y :  119 || w :  64 || h : 136
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  109 || y :  82 || w :  74 || h : 164
#
# Bounding box coordinates in the frame :  x :  366 || y :  73 || w :  92 || h : 179
#
# Bounding box coordinates in the frame :  x :  457 || y :  91 || w :  138 || h : 265
#
# Bounding box coordinates in the frame :  x :  259 || y :  119 || w :  65 || h : 135
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  109 || y :  82 || w :  78 || h : 161
#
# Bounding box coordinates in the frame :  x :  364 || y :  74 || w :  92 || h : 173
#
# Bounding box coordinates in the frame :  x :  456 || y :  88 || w :  141 || h : 271
#
# Bounding box coordinates in the frame :  x :  260 || y :  118 || w :  63 || h : 135
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  103 || y :  75 || w :  77 || h : 174
#
# Bounding box coordinates in the frame :  x :  362 || y :  73 || w :  91 || h : 172
#
# Bounding box coordinates in the frame :  x :  252 || y :  120 || w :  61 || h : 129
#
# Bounding box coordinates in the frame :  x :  454 || y :  86 || w :  141 || h : 274
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  358 || y :  69 || w :  94 || h : 177
#
# Bounding box coordinates in the frame :  x :  94 || y :  74 || w :  86 || h : 169
#
# Bounding box coordinates in the frame :  x :  451 || y :  77 || w :  148 || h : 289
#
# Bounding box coordinates in the frame :  x :  252 || y :  114 || w :  59 || h : 136
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  357 || y :  67 || w :  96 || h : 178
#
# Bounding box coordinates in the frame :  x :  248 || y :  103 || w :  66 || h : 146
#
# Bounding box coordinates in the frame :  x :  81 || y :  47 || w :  83 || h : 213
#
# Bounding box coordinates in the frame :  x :  451 || y :  74 || w :  148 || h : 296
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  356 || y :  59 || w :  93 || h : 193
#
# Bounding box coordinates in the frame :  x :  66 || y :  75 || w :  100 || h : 163
#
# Bounding box coordinates in the frame :  x :  247 || y :  102 || w :  66 || h : 149
#
# Bounding box coordinates in the frame :  x :  449 || y :  72 || w :  149 || h : 300
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  356 || y :  59 || w :  93 || h : 193
#
# Bounding box coordinates in the frame :  x :  66 || y :  75 || w :  100 || h : 163
#
# Bounding box coordinates in the frame :  x :  247 || y :  102 || w :  66 || h : 148
#
# Bounding box coordinates in the frame :  x :  450 || y :  74 || w :  148 || h : 298
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  354 || y :  64 || w :  96 || h : 185
#
# Bounding box coordinates in the frame :  x :  62 || y :  75 || w :  109 || h : 160
#
# Bounding box coordinates in the frame :  x :  246 || y :  101 || w :  66 || h : 152
#
# Bounding box coordinates in the frame :  x :  449 || y :  79 || w :  150 || h : 286
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  351 || y :  66 || w :  99 || h : 183
#
# Bounding box coordinates in the frame :  x :  62 || y :  71 || w :  106 || h : 171
#
# Bounding box coordinates in the frame :  x :  242 || y :  113 || w :  66 || h : 140
#
# Bounding box coordinates in the frame :  x :  447 || y :  80 || w :  152 || h : 285
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  65 || y :  70 || w :  96 || h : 172
#
# Bounding box coordinates in the frame :  x :  349 || y :  65 || w :  97 || h : 188
#
# Bounding box coordinates in the frame :  x :  242 || y :  112 || w :  64 || h : 145
#
# Bounding box coordinates in the frame :  x :  448 || y :  81 || w :  151 || h : 284
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  66 || y :  70 || w :  93 || h : 174
#
# Bounding box coordinates in the frame :  x :  237 || y :  114 || w :  69 || h : 140
#
# Bounding box coordinates in the frame :  x :  347 || y :  61 || w :  101 || h : 194
#
# Bounding box coordinates in the frame :  x :  433 || y :  65 || w :  187 || h : 314
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  64 || y :  72 || w :  95 || h : 172
#
# Bounding box coordinates in the frame :  x :  236 || y :  110 || w :  68 || h : 147
#
# Bounding box coordinates in the frame :  x :  347 || y :  58 || w :  97 || h : 197
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  64 || y :  72 || w :  95 || h : 172
#
# Bounding box coordinates in the frame :  x :  236 || y :  110 || w :  68 || h : 147
#
# Bounding box coordinates in the frame :  x :  347 || y :  58 || w :  97 || h : 197
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  64 || y :  74 || w :  94 || h : 166
#
# Bounding box coordinates in the frame :  x :  235 || y :  112 || w :  68 || h : 143
#
# Bounding box coordinates in the frame :  x :  340 || y :  34 || w :  98 || h : 241
#
# Bounding box coordinates in the frame :  x :  448 || y :  85 || w :  165 || h : 244
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  61 || y :  73 || w :  97 || h : 163
#
# Bounding box coordinates in the frame :  x :  236 || y :  97 || w :  68 || h : 159
#
# Bounding box coordinates in the frame :  x :  345 || y :  49 || w :  98 || h : 217
#
# Bounding box coordinates in the frame :  x :  446 || y :  81 || w :  166 || h : 250
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  59 || y :  74 || w :  94 || h : 164
#
# Bounding box coordinates in the frame :  x :  233 || y :  109 || w :  68 || h : 146
#
# Bounding box coordinates in the frame :  x :  340 || y :  44 || w :  97 || h : 226
#
# Bounding box coordinates in the frame :  x :  444 || y :  82 || w :  170 || h : 250
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  58 || y :  71 || w :  91 || h : 168
#
# Bounding box coordinates in the frame :  x :  230 || y :  108 || w :  70 || h : 147
#
# Bounding box coordinates in the frame :  x :  338 || y :  39 || w :  103 || h : 233
#
# Bounding box coordinates in the frame :  x :  445 || y :  84 || w :  167 || h : 246
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  58 || y :  69 || w :  89 || h : 173
#
# Bounding box coordinates in the frame :  x :  230 || y :  109 || w :  70 || h : 148
#
# Bounding box coordinates in the frame :  x :  318 || y :  53 || w :  115 || h : 210
#
# Bounding box coordinates in the frame :  x :  455 || y :  42 || w :  145 || h : 338
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  58 || y :  70 || w :  89 || h : 173
#
# Bounding box coordinates in the frame :  x :  229 || y :  109 || w :  71 || h : 147
#
# Bounding box coordinates in the frame :  x :  318 || y :  52 || w :  115 || h : 210
#
# Bounding box coordinates in the frame :  x :  454 || y :  42 || w :  145 || h : 337
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  57 || y :  64 || w :  82 || h : 184
#
# Bounding box coordinates in the frame :  x :  226 || y :  110 || w :  72 || h : 146
#
# Bounding box coordinates in the frame :  x :  337 || y :  20 || w :  88 || h : 272
#
# Bounding box coordinates in the frame :  x :  445 || y :  78 || w :  168 || h : 258
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  53 || y :  68 || w :  82 || h : 177
#
# Bounding box coordinates in the frame :  x :  442 || y :  74 || w :  176 || h : 265
#
# Bounding box coordinates in the frame :  x :  225 || y :  110 || w :  72 || h : 148
#
# Bounding box coordinates in the frame :  x :  319 || y :  50 || w :  113 || h : 217
#
# Number of objects detected :  4
# Bounding box coordinates in the frame :  x :  53 || y :  71 || w :  82 || h : 173
#
# Bounding box coordinates in the frame :  x :  224 || y :  107 || w :  74 || h : 156
#
# Bounding box coordinates in the frame :  x :  323 || y :  49 || w :  106 || h : 219
#
# Bounding box coordinates in the frame :  x :  438 || y :  78 || w :  183 || h : 256
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  52 || y :  69 || w :  81 || h : 175
#
# Bounding box coordinates in the frame :  x :  441 || y :  80 || w :  178 || h : 252
#
# Bounding box coordinates in the frame :  x :  325 || y :  45 || w :  103 || h : 231
#
# Bounding box coordinates in the frame :  x :  221 || y :  108 || w :  76 || h : 155
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  48 || y :  68 || w :  85 || h : 180
#
# Bounding box coordinates in the frame :  x :  447 || y :  81 || w :  169 || h : 251
#
# Bounding box coordinates in the frame :  x :  221 || y :  109 || w :  77 || h : 158
#
# Bounding box coordinates in the frame :  x :  321 || y :  44 || w :  112 || h : 235
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  48 || y :  68 || w :  85 || h : 180
#
# Bounding box coordinates in the frame :  x :  447 || y :  81 || w :  169 || h : 250
#
# Bounding box coordinates in the frame :  x :  221 || y :  109 || w :  77 || h : 159
#
# Bounding box coordinates in the frame :  x :  321 || y :  44 || w :  112 || h : 235
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  42 || y :  68 || w :  89 || h : 182
#
# Bounding box coordinates in the frame :  x :  443 || y :  79 || w :  178 || h : 255
#
# Bounding box coordinates in the frame :  x :  220 || y :  109 || w :  78 || h : 159
#
# Bounding box coordinates in the frame :  x :  336 || y :  44 || w :  118 || h : 238
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  40 || y :  74 || w :  94 || h : 174
#
# Bounding box coordinates in the frame :  x :  333 || y :  50 || w :  127 || h : 225
#
# Bounding box coordinates in the frame :  x :  220 || y :  108 || w :  78 || h : 163
#
# Bounding box coordinates in the frame :  x :  450 || y :  75 || w :  167 || h : 265
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  41 || y :  74 || w :  97 || h : 180
#
# Bounding box coordinates in the frame :  x :  340 || y :  49 || w :  117 || h : 232
#
# Bounding box coordinates in the frame :  x :  453 || y :  65 || w :  152 || h : 315
#
# Bounding box coordinates in the frame :  x :  220 || y :  110 || w :  77 || h : 167
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  39 || y :  78 || w :  99 || h : 173
#
# Bounding box coordinates in the frame :  x :  344 || y :  31 || w :  99 || h : 279
#
# Bounding box coordinates in the frame :  x :  458 || y :  67 || w :  145 || h : 312
#
# Bounding box coordinates in the frame :  x :  224 || y :  120 || w :  74 || h : 149
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  38 || y :  81 || w :  106 || h : 171
#
# Bounding box coordinates in the frame :  x :  343 || y :  53 || w :  116 || h : 226
#
# Bounding box coordinates in the frame :  x :  458 || y :  72 || w :  146 || h : 304
#
# Bounding box coordinates in the frame :  x :  223 || y :  120 || w :  76 || h : 150
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  38 || y :  81 || w :  106 || h : 171
#
# Bounding box coordinates in the frame :  x :  343 || y :  53 || w :  116 || h : 227
#
# Bounding box coordinates in the frame :  x :  458 || y :  72 || w :  146 || h : 304
#
# Bounding box coordinates in the frame :  x :  223 || y :  120 || w :  76 || h : 150
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  38 || y :  78 || w :  101 || h : 175
#
# Bounding box coordinates in the frame :  x :  350 || y :  64 || w :  113 || h : 205
#
# Bounding box coordinates in the frame :  x :  227 || y :  115 || w :  82 || h : 159
#
# Bounding box coordinates in the frame :  x :  460 || y :  78 || w :  147 || h : 292
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  41 || y :  80 || w :  98 || h : 174
#
# Bounding box coordinates in the frame :  x :  227 || y :  117 || w :  84 || h : 155
#
# Bounding box coordinates in the frame :  x :  354 || y :  64 || w :  109 || h : 208
#
# Bounding box coordinates in the frame :  x :  460 || y :  81 || w :  149 || h : 285
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  228 || y :  117 || w :  85 || h : 150
#
# Bounding box coordinates in the frame :  x :  41 || y :  54 || w :  87 || h : 233
#
# Bounding box coordinates in the frame :  x :  354 || y :  68 || w :  114 || h : 197
#
# Bounding box coordinates in the frame :  x :  462 || y :  89 || w :  147 || h : 269
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  47 || y :  79 || w :  105 || h : 175
#
# Bounding box coordinates in the frame :  x :  358 || y :  65 || w :  116 || h : 201
#
# Bounding box coordinates in the frame :  x :  238 || y :  111 || w :  72 || h : 164
#
# Bounding box coordinates in the frame :  x :  444 || y :  97 || w :  205 || h : 218
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  47 || y :  78 || w :  112 || h : 175
#
# Bounding box coordinates in the frame :  x :  240 || y :  115 || w :  76 || h : 157
#
# Bounding box coordinates in the frame :  x :  358 || y :  66 || w :  121 || h : 201
#
# Bounding box coordinates in the frame :  x :  460 || y :  109 || w :  174 || h : 195
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  47 || y :  78 || w :  113 || h : 175
#
# Bounding box coordinates in the frame :  x :  240 || y :  115 || w :  76 || h : 156
#
# Bounding box coordinates in the frame :  x :  358 || y :  66 || w :  121 || h : 201
#
# Bounding box coordinates in the frame :  x :  461 || y :  110 || w :  174 || h : 194
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  60 || y :  73 || w :  102 || h : 176
#
# Bounding box coordinates in the frame :  x :  365 || y :  62 || w :  112 || h : 203
#
# Bounding box coordinates in the frame :  x :  244 || y :  114 || w :  76 || h : 157
#
# Bounding box coordinates in the frame :  x :  470 || y :  105 || w :  159 || h : 203
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  370 || y :  65 || w :  105 || h : 195
#
# Bounding box coordinates in the frame :  x :  69 || y :  75 || w :  95 || h : 176
#
# Bounding box coordinates in the frame :  x :  251 || y :  111 || w :  83 || h : 159
#
# Bounding box coordinates in the frame :  x :  455 || y :  93 || w :  189 || h : 229
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  108 || y :  74 || w :  80 || h : 178
#
# Bounding box coordinates in the frame :  x :  269 || y :  119 || w :  68 || h : 140
#
# Bounding box coordinates in the frame :  x :  382 || y :  66 || w :  90 || h : 196
#
# Bounding box coordinates in the frame :  x :  452 || y :  107 || w :  190 || h : 242
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  125 || y :  74 || w :  81 || h : 172
#
# Bounding box coordinates in the frame :  x :  387 || y :  61 || w :  83 || h : 201
#
# Bounding box coordinates in the frame :  x :  278 || y :  120 || w :  65 || h : 134
#
# Bounding box coordinates in the frame :  x :  452 || y :  109 || w :  188 || h : 235
#
# Number of objects detected :  5
#
# Bounding box coordinates in the frame :  x :  391 || y :  81 || w :  82 || h : 159
#
# Bounding box coordinates in the frame :  x :  464 || y :  112 || w :  172 || h : 232
#
# Bounding box coordinates in the frame :  x :  282 || y :  134 || w :  69 || h : 97
#
# Bounding box coordinates in the frame :  x :  138 || y :  71 || w :  74 || h : 189
#
# Bounding box coordinates in the frame :  x :  162 || y :  0 || w :  114 || h : 83
#
# Number of objects detected :  5
#
# Bounding box coordinates in the frame :  x :  391 || y :  81 || w :  82 || h : 159
#
# Bounding box coordinates in the frame :  x :  464 || y :  112 || w :  171 || h : 232
#
# Bounding box coordinates in the frame :  x :  282 || y :  134 || w :  69 || h : 97
#
# Bounding box coordinates in the frame :  x :  138 || y :  71 || w :  74 || h : 189
#
# Bounding box coordinates in the frame :  x :  160 || y :  0 || w :  115 || h : 82
#
# Number of objects detected :  5
#
# Bounding box coordinates in the frame :  x :  385 || y :  91 || w :  97 || h : 139
#
# Bounding box coordinates in the frame :  x :  299 || y :  135 || w :  63 || h : 93
#
# Bounding box coordinates in the frame :  x :  161 || y :  87 || w :  84 || h : 144
#
# Bounding box coordinates in the frame :  x :  462 || y :  117 || w :  167 || h : 226
#
# Bounding box coordinates in the frame :  x :  175 || y :  -1 || w :  112 || h : 88
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  310 || y :  117 || w :  57 || h : 119
#
# Bounding box coordinates in the frame :  x :  397 || y :  78 || w :  72 || h : 161
#
# Bounding box coordinates in the frame :  x :  171 || y :  82 || w :  76 || h : 151
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  316 || y :  127 || w :  56 || h : 96
#
# Bounding box coordinates in the frame :  x :  400 || y :  82 || w :  70 || h : 149
#
# Bounding box coordinates in the frame :  x :  177 || y :  91 || w :  80 || h : 131
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  402 || y :  90 || w :  69 || h : 133
#
# Bounding box coordinates in the frame :  x :  328 || y :  124 || w :  55 || h : 102
#
# Bounding box coordinates in the frame :  x :  202 || y :  87 || w :  72 || h : 139
#
# Bounding box coordinates in the frame :  x :  483 || y :  124 || w :  127 || h : 219
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  406 || y :  91 || w :  63 || h : 125
#
# Bounding box coordinates in the frame :  x :  335 || y :  128 || w :  53 || h : 90
#
# Bounding box coordinates in the frame :  x :  209 || y :  95 || w :  70 || h : 123
#
# Bounding box coordinates in the frame :  x :  485 || y :  132 || w :  120 || h : 202
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  334 || y :  128 || w :  53 || h : 90
#
# Bounding box coordinates in the frame :  x :  406 || y :  91 || w :  63 || h : 125
#
# Bounding box coordinates in the frame :  x :  209 || y :  95 || w :  70 || h : 123
#
# Bounding box coordinates in the frame :  x :  485 || y :  132 || w :  119 || h : 203
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  406 || y :  90 || w :  61 || h : 125
#
# Bounding box coordinates in the frame :  x :  338 || y :  126 || w :  50 || h : 90
#
# Bounding box coordinates in the frame :  x :  217 || y :  95 || w :  65 || h : 122
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  332 || y :  125 || w :  58 || h : 87
#
# Bounding box coordinates in the frame :  x :  401 || y :  89 || w :  53 || h : 125
#
# Bounding box coordinates in the frame :  x :  220 || y :  94 || w :  59 || h : 118
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  396 || y :  100 || w :  55 || h : 97
#
# Bounding box coordinates in the frame :  x :  335 || y :  126 || w :  40 || h : 77
#
# Bounding box coordinates in the frame :  x :  220 || y :  91 || w :  58 || h : 116
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  324 || y :  109 || w :  43 || h : 80
#
# Bounding box coordinates in the frame :  x :  224 || y :  76 || w :  50 || h : 110
#
# Bounding box coordinates in the frame :  x :  393 || y :  73 || w :  53 || h : 125
#
# Number of objects detected :  3
#
# ...
#
# Bounding box coordinates in the frame :  x :  526 || y :  174 || w :  16 || h : 26
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  255 || y :  161 || w :  34 || h : 55
#
# Bounding box coordinates in the frame :  x :  428 || y :  4 || w :  31 || h : 48
#
# Bounding box coordinates in the frame :  x :  510 || y :  174 || w :  20 || h : 27
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  423 || y :  0 || w :  37 || h : 55
#
# Bounding box coordinates in the frame :  x :  247 || y :  162 || w :  38 || h : 55
#
# Bounding box coordinates in the frame :  x :  540 || y :  170 || w :  17 || h : 31
#
# Bounding box coordinates in the frame :  x :  510 || y :  174 || w :  16 || h : 26
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  421 || y :  1 || w :  35 || h : 54
#
# Bounding box coordinates in the frame :  x :  248 || y :  162 || w :  38 || h : 55
#
# Bounding box coordinates in the frame :  x :  541 || y :  170 || w :  15 || h : 33
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  418 || y :  3 || w :  35 || h : 54
#
# Bounding box coordinates in the frame :  x :  251 || y :  161 || w :  34 || h : 59
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  415 || y :  5 || w :  31 || h : 53
#
# Bounding box coordinates in the frame :  x :  524 || y :  184 || w :  14 || h : 22
#
# Bounding box coordinates in the frame :  x :  244 || y :  160 || w :  35 || h : 64
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  416 || y :  5 || w :  31 || h : 53
#
# Bounding box coordinates in the frame :  x :  524 || y :  184 || w :  14 || h : 22
#
# Bounding box coordinates in the frame :  x :  244 || y :  160 || w :  35 || h : 64
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  413 || y :  6 || w :  31 || h : 53
#
# Bounding box coordinates in the frame :  x :  250 || y :  166 || w :  25 || h : 53
#
# Bounding box coordinates in the frame :  x :  515 || y :  182 || w :  14 || h : 22
#
# Bounding box coordinates in the frame :  x :  494 || y :  181 || w :  20 || h : 21
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  409 || y :  7 || w :  35 || h : 53
#
# Bounding box coordinates in the frame :  x :  494 || y :  180 || w :  18 || h : 28
#
# Bounding box coordinates in the frame :  x :  249 || y :  168 || w :  25 || h : 52
#
# Bounding box coordinates in the frame :  x :  525 || y :  178 || w :  18 || h : 29
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  407 || y :  7 || w :  36 || h : 53
#
# Bounding box coordinates in the frame :  x :  246 || y :  167 || w :  28 || h : 55
#
# Bounding box coordinates in the frame :  x :  526 || y :  179 || w :  14 || h : 31
#
# Bounding box coordinates in the frame :  x :  493 || y :  182 || w :  18 || h : 28
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  412 || y :  12 || w :  28 || h : 53
#
# Bounding box coordinates in the frame :  x :  525 || y :  181 || w :  15 || h : 30
#
# Bounding box coordinates in the frame :  x :  245 || y :  169 || w :  28 || h : 53
#
# Bounding box coordinates in the frame :  x :  493 || y :  181 || w :  16 || h : 30
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  411 || y :  14 || w :  29 || h : 54
#
# Bounding box coordinates in the frame :  x :  231 || y :  168 || w :  37 || h : 55
#
# Bounding box coordinates in the frame :  x :  493 || y :  188 || w :  18 || h : 23
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  411 || y :  14 || w :  29 || h : 54
# Bounding box coordinates in the frame :  x :  231 || y :  168 || w :  37 || h : 55
#
# Bounding box coordinates in the frame :  x :  493 || y :  188 || w :  18 || h : 23
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  409 || y :  14 || w :  30 || h : 53
#
# Bounding box coordinates in the frame :  x :  231 || y :  167 || w :  36 || h : 56
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  409 || y :  15 || w :  30 || h : 52
#
# Bounding box coordinates in the frame :  x :  233 || y :  166 || w :  36 || h : 57
#
# Bounding box coordinates in the frame :  x :  511 || y :  192 || w :  12 || h : 16
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  408 || y :  15 || w :  30 || h : 53
#
# Bounding box coordinates in the frame :  x :  232 || y :  166 || w :  36 || h : 57
#
# Bounding box coordinates in the frame :  x :  510 || y :  191 || w :  13 || h : 19
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  230 || y :  167 || w :  38 || h : 55
#
# Bounding box coordinates in the frame :  x :  509 || y :  192 || w :  13 || h : 20
#
# Bounding box coordinates in the frame :  x :  409 || y :  14 || w :  29 || h : 54
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  509 || y :  192 || w :  14 || h : 20
#
# Bounding box coordinates in the frame :  x :  231 || y :  168 || w :  37 || h : 53
#
# Bounding box coordinates in the frame :  x :  408 || y :  15 || w :  29 || h : 54
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  509 || y :  193 || w :  14 || h : 20
#
# Bounding box coordinates in the frame :  x :  231 || y :  168 || w :  37 || h : 53
#
# Bounding box coordinates in the frame :  x :  408 || y :  15 || w :  30 || h : 54
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  408 || y :  16 || w :  30 || h : 53
#
# Bounding box coordinates in the frame :  x :  508 || y :  193 || w :  14 || h : 21
#
# Bounding box coordinates in the frame :  x :  232 || y :  167 || w :  35 || h : 56
#
# Bounding box coordinates in the frame :  x :  477 || y :  189 || w :  23 || h : 23
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  508 || y :  193 || w :  14 || h : 21
#
# Bounding box coordinates in the frame :  x :  407 || y :  16 || w :  31 || h : 53
#
# Bounding box coordinates in the frame :  x :  232 || y :  167 || w :  36 || h : 56
#
# Bounding box coordinates in the frame :  x :  478 || y :  190 || w :  22 || h : 22
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  408 || y :  15 || w :  30 || h : 54
#
# Bounding box coordinates in the frame :  x :  232 || y :  167 || w :  36 || h : 55
#
# Bounding box coordinates in the frame :  x :  508 || y :  194 || w :  14 || h : 20
#
# Bounding box coordinates in the frame :  x :  479 || y :  190 || w :  21 || h : 22
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  407 || y :  16 || w :  31 || h : 53
#
# Bounding box coordinates in the frame :  x :  232 || y :  166 || w :  36 || h : 59
#
# Bounding box coordinates in the frame :  x :  508 || y :  193 || w :  15 || h : 22
#
# Bounding box coordinates in the frame :  x :  478 || y :  190 || w :  21 || h : 21
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  478 || y :  191 || w :  22 || h : 21
#
# Bounding box coordinates in the frame :  x :  406 || y :  16 || w :  33 || h : 54
#
# Bounding box coordinates in the frame :  x :  508 || y :  193 || w :  14 || h : 21
#
# Bounding box coordinates in the frame :  x :  231 || y :  167 || w :  37 || h : 57
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  478 || y :  191 || w :  22 || h : 21
#
# Bounding box coordinates in the frame :  x :  406 || y :  16 || w :  33 || h : 54
#
# Bounding box coordinates in the frame :  x :  508 || y :  193 || w :  14 || h : 21
#
# Bounding box coordinates in the frame :  x :  231 || y :  167 || w :  37 || h : 57
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  406 || y :  16 || w :  33 || h : 54
#
# Bounding box coordinates in the frame :  x :  479 || y :  190 || w :  21 || h : 22
#
# Bounding box coordinates in the frame :  x :  508 || y :  193 || w :  14 || h : 21
#
# Bounding box coordinates in the frame :  x :  232 || y :  167 || w :  36 || h : 57
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  407 || y :  15 || w :  32 || h : 54
#
# Bounding box coordinates in the frame :  x :  508 || y :  193 || w :  14 || h : 21
#
# Bounding box coordinates in the frame :  x :  479 || y :  190 || w :  21 || h : 22
#
# Bounding box coordinates in the frame :  x :  233 || y :  167 || w :  35 || h : 57
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  406 || y :  16 || w :  32 || h : 54
#
# Bounding box coordinates in the frame :  x :  479 || y :  190 || w :  21 || h : 21
#
# Bounding box coordinates in the frame :  x :  230 || y :  166 || w :  38 || h : 58
#
# Bounding box coordinates in the frame :  x :  508 || y :  193 || w :  14 || h : 22
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  229 || y :  168 || w :  40 || h : 55
#
# Bounding box coordinates in the frame :  x :  479 || y :  190 || w :  20 || h : 22
#
# Bounding box coordinates in the frame :  x :  405 || y :  16 || w :  33 || h : 53
#
# Bounding box coordinates in the frame :  x :  507 || y :  193 || w :  14 || h : 22
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  229 || y :  167 || w :  39 || h : 56
#
# Bounding box coordinates in the frame :  x :  406 || y :  16 || w :  32 || h : 52
#
# Bounding box coordinates in the frame :  x :  480 || y :  191 || w :  18 || h : 20
#
# Bounding box coordinates in the frame :  x :  508 || y :  193 || w :  13 || h : 21
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  229 || y :  167 || w :  39 || h : 55
#
# Bounding box coordinates in the frame :  x :  406 || y :  16 || w :  32 || h : 52
#
# Bounding box coordinates in the frame :  x :  480 || y :  191 || w :  18 || h : 20
#
# Bounding box coordinates in the frame :  x :  508 || y :  193 || w :  13 || h : 20
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  231 || y :  168 || w :  37 || h : 54
#
# Bounding box coordinates in the frame :  x :  407 || y :  16 || w :  31 || h : 52
#
# Bounding box coordinates in the frame :  x :  509 || y :  193 || w :  14 || h : 19
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  232 || y :  166 || w :  36 || h : 55
#
# Bounding box coordinates in the frame :  x :  407 || y :  15 || w :  31 || h : 52
#
# Bounding box coordinates in the frame :  x :  510 || y :  192 || w :  15 || h : 19
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  231 || y :  166 || w :  36 || h : 57
#
# Bounding box coordinates in the frame :  x :  408 || y :  13 || w :  30 || h : 54
#
# Bounding box coordinates in the frame :  x :  509 || y :  192 || w :  13 || h : 18
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  230 || y :  166 || w :  36 || h : 56
#
# Bounding box coordinates in the frame :  x :  408 || y :  13 || w :  31 || h : 53
#
# Bounding box coordinates in the frame :  x :  509 || y :  193 || w :  14 || h : 18
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  232 || y :  164 || w :  35 || h : 60
#
# Bounding box coordinates in the frame :  x :  409 || y :  12 || w :  30 || h : 55
#
# Bounding box coordinates in the frame :  x :  510 || y :  192 || w :  13 || h : 16
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  232 || y :  164 || w :  34 || h : 60
#
# Bounding box coordinates in the frame :  x :  409 || y :  12 || w :  30 || h : 55
#
# Bounding box coordinates in the frame :  x :  510 || y :  192 || w :  13 || h : 16
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  232 || y :  165 || w :  36 || h : 57
#
# Bounding box coordinates in the frame :  x :  411 || y :  11 || w :  30 || h : 54
#
# Bounding box coordinates in the frame :  x :  493 || y :  183 || w :  16 || h : 28
#
# Bounding box coordinates in the frame :  x :  524 || y :  181 || w :  15 || h : 28
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  406 || y :  7 || w :  39 || h : 53
#
# Bounding box coordinates in the frame :  x :  232 || y :  165 || w :  36 || h : 55
#
# Bounding box coordinates in the frame :  x :  492 || y :  183 || w :  18 || h : 26
#
# Bounding box coordinates in the frame :  x :  526 || y :  181 || w :  13 || h : 26
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  407 || y :  7 || w :  36 || h : 51
#
# Bounding box coordinates in the frame :  x :  493 || y :  182 || w :  18 || h : 25
#
# Bounding box coordinates in the frame :  x :  234 || y :  161 || w :  32 || h : 58
#
# Bounding box coordinates in the frame :  x :  526 || y :  180 || w :  14 || h : 28
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  413 || y :  4 || w :  31 || h : 53
#
# Bounding box coordinates in the frame :  x :  234 || y :  162 || w :  32 || h : 54
#
# Bounding box coordinates in the frame :  x :  492 || y :  180 || w :  20 || h : 25
#
# Bounding box coordinates in the frame :  x :  526 || y :  179 || w :  16 || h : 28
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  414 || y :  3 || w :  33 || h : 51
#
# Bounding box coordinates in the frame :  x :  253 || y :  154 || w :  23 || h : 63
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  414 || y :  3 || w :  33 || h : 51
#
# Bounding box coordinates in the frame :  x :  253 || y :  154 || w :  23 || h : 63
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  416 || y :  0 || w :  36 || h : 54
#
# Bounding box coordinates in the frame :  x :  242 || y :  152 || w :  40 || h : 66
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  420 || y :  -2 || w :  38 || h : 52
#
# Bounding box coordinates in the frame :  x :  496 || y :  172 || w :  21 || h : 26
#
# Bounding box coordinates in the frame :  x :  524 || y :  174 || w :  16 || h : 26
#
# Bounding box coordinates in the frame :  x :  248 || y :  153 || w :  37 || h : 50
#
# Number of objects detected :  4
#
# Bounding box coordinates in the frame :  x :  247 || y :  152 || w :  41 || h : 51
#
# Bounding box coordinates in the frame :  x :  430 || y :  0 || w :  27 || h : 48
#
# Bounding box coordinates in the frame :  x :  529 || y :  170 || w :  14 || h : 24
#
# Bounding box coordinates in the frame :  x :  508 || y :  170 || w :  22 || h : 24
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  430 || y :  0 || w :  28 || h : 44
#
# Bounding box coordinates in the frame :  x :  250 || y :  148 || w :  38 || h : 57
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  252 || y :  147 || w :  37 || h : 56
#
# Bounding box coordinates in the frame :  x :  428 || y :  -1 || w :  29 || h : 45
#
# Number of objects detected :  2
#
# Bounding box coordinates in the frame :  x :  252 || y :  147 || w :  37 || h : 56
#
# Bounding box coordinates in the frame :  x :  428 || y :  -1 || w :  29 || h : 45
#
# Number of objects detected :  3
#
# Bounding box coordinates in the frame :  x :  256 || y :  148 || w :  38 || h : 53
#
# Bounding box coordinates in the frame :  x :  437 || y :  0 || w :  33 || h : 42
#
# Bounding box coordinates in the frame :  x :  451 || y :  85 || w :  38 || h : 65
#
# Number of objects detected :  5
#
# Bounding box coordinates in the frame :  x :  258 || y :  146 || w :  36 || h : 53
#
# Bounding box coordinates in the frame :  x :  541 || y :  166 || w :  16 || h : 20
#
# Bounding box coordinates in the frame :  x :  523 || y :  163 || w :  19 || h : 26
#
# Bounding box coordinates in the frame :  x :  440 || y :  -1 || w :  30 || h : 38
#
# Bounding box coordinates in the frame :  x :  556 || y :  162 || w :  15 || h : 26
#
# Can't receive frame (stream end?). Exiting ...
